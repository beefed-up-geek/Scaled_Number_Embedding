# %%
# 기존 라이브러리 제거
# !pip uninstall -y torch torchvision transformers timm

# pip 최신화
# !pip install --upgrade pip

# PyTorch/torchvision 설치 (CUDA 11.8 기준 예시)
# !pip install torch==2.0.1 torchvision==0.15.2 --extra-index-url https://download.pytorch.org/whl/cu118

# transformers, timm 설치 (필요 시 accelerate 등도 함께 설치 가능)
# !pip install transformers==4.31.0 timm

# 필요한 경우, 아래처럼 추가 라이브러리를 설치할 수도 있습니다.
# !pip install accelerate
# !pip install huggingface_hub
# Out:
# Found existing installation: torch 2.6.0
# Uninstalling torch-2.6.0:
#   Successfully uninstalled torch-2.6.0
# Found existing installation: torchvision 0.20.1+cu124
# Uninstalling torchvision-0.20.1+cu124:
#   Successfully uninstalled torchvision-0.20.1+cu124
# Found existing installation: transformers 4.49.0
# Uninstalling transformers-4.49.0:
#   Successfully uninstalled transformers-4.49.0
# Found existing installation: timm 1.0.15
# Uninstalling timm-1.0.15:
#   Successfully uninstalled timm-1.0.15
# ...
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 21.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 104.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 131.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
# ...

# %%
from huggingface_hub import login

login()

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np

model_name = "deepseek-ai/deepseek-math-7b-rl"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model = AutoModel.from_pretrained(model_name)

# 확인할 입력들
inputs_list = ["1", "01", "001", "0001"]

for inp in inputs_list:
    # 토크나이징
    tokens = tokenizer(inp, return_tensors="pt")

    # 출력용
    print("입력 문자열:", inp)
    print("토크나이즈 결과 (input_ids):", tokens["input_ids"])
    print("토크나이즈 결과 (attention_mask):", tokens["attention_mask"])

    # 모델에 입력하여 임베딩 추출
    with torch.no_grad():
        outputs = model(**tokens)

    # 첫 번째 토큰의 히든 상태 벡터 사용
    embedding = outputs.last_hidden_state[:, 1, :].squeeze(0).cpu().numpy()

    # 임베딩 출력
    print("임베딩 벡터 (첫 번째 토큰):", embedding)
    print("-" * 50)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np
import pandas as pd

# 모델 및 토크나이저 불러오기
model_name = "deepseek-ai/deepseek-math-7b-rl"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model = AutoModel.from_pretrained(model_name)#, trust_remote_code=True)

# 저장할 숫자 리스트 (0 ~ 10)
numbers = [str(i) for i in range(11)]  # 숫자를 문자열로 변환하여 리스트 생성

# 숫자별 임베딩 저장 리스트
embedding_list = []

# 숫자별 임베딩 추출
for num in numbers:
    # 토큰 변환
    inputs = tokenizer(num, return_tensors="pt")

    # 모델에 입력하여 임베딩 추출
    with torch.no_grad():
        outputs = model(**inputs)

    # 첫 번째 토큰의 히든 상태 벡터 사용
    embedding = outputs.last_hidden_state[:, 1, :].squeeze(0).cpu().numpy()

    # 데이터 저장 (리스트로 변환 후 추가)
    embedding_list.append([num] + embedding.tolist())

# 데이터프레임 생성 및 CSV 저장
embedding_dim = embedding.shape[0]
columns = ["key"] + [f"dim_{i+1}" for i in range(embedding_dim)]
df = pd.DataFrame(embedding_list, columns=columns)
df.to_csv("deepseek_embeddings.csv", index=False)

# 저장된 데이터 확인
print("CSV 파일 저장 완료")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...
